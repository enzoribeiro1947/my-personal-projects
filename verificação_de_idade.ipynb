# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/verifica%C3%A7%C3%A3o_de_idade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("digite a sua idade "))

if idade > 17:
  print("você é maior de idade")
else:
  print("você é menor de idade")
