# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/top3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
top3 = []
top1pedido =str(input("adicione um top 1 a lista "))
top3.insert (0, top1pedido)
top2pedido =str(input("adicione um top 2 a lista "))
top3.insert (1, top2pedido)
top3pedido =str(input("adicione um top 3 a lista "))
top3.insert (2, top3pedido)
print(top3)
