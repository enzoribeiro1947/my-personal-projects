# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/sistema_de_notas_escolares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota = int(input("qual a sua nota? "))

if nota >= 5:
  print("você passou")
  if nota >= 7:
    print("parabéns! Seu desempenho foi acima da média")
else:
  print("você não passou")
# Out:
# qual a sua nota? 10
# você passou
# parabéns! Seu desempenho foi acima da média
