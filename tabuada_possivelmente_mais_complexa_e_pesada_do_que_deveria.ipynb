# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/tabuada_possivelmente_mais_complexa_e_pesada_do_que_deveria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t1 = 1
t2 = 2
t3 = 3
t4 = 4
t5 = 5
t6 = 6
t7 = 7
t8 = 8
t9 = 9
t10 = 10

tabuada_do_1 = t1*t1, t1*t2, t1*t3, t1*t4, t1*t5, t1*t6, t1*t7, t1*t8, t1*t9, t1*t10
tabuada_do_2 = t2*t1, t2*t2, t2*t3, t2*t4, t2*t5, t2*t6, t2*t7, t2*t8, t2*t9, t2*t10
tabuada_do_3 = t3*t1, t3*t2, t3*t3, t3*t4, t3*t5, t3*t6, t3*t7, t3*t8, t3*t9, t3*t10
tabuada_do_4 = t4*t1, t4*t2, t4*t3, t4*t4, t4*t5, t4*t6, t4*t7, t4*t8, t4*t9, t4*t10
tabuada_do_5 = t5*t1, t5*t2, t5*t3, t5*t4, t5*t5, t5*t6, t5*t7, t5*t8, t5*t9, t5*t10
tabuada_do_6 = t6*t1, t6*t2, t6*t3, t6*t4, t6*t5, t6*t6, t6*t7, t6*t8, t6*t9, t6*t10
tabuada_do_7 = t7*t1, t7*t2, t7*t3, t7*t4, t7*t5, t7*t6, t7*t7, t7*t8, t7*t9, t7*t10
tabuada_do_8 = t8*t1, t8*t2, t8*t3, t8*t4, t8*t5, t8*t6, t8*t7, t8*t8, t8*t9, t8*t10
tabuada_do_9 = t9*t1, t9*t2, t9*t3, t9*t4, t9*t5, t9*t6, t9*t7, t9*t8, t9*t9, t9*t10
tabuada_do_10 = t10*t1, t10*t2, t10*t3, t10*t4, t10*t5, t10*t6, t10*t7, t10*t8, t10*t9, t10*t10

print("printe qual tabuada de 1 a 10 tu desejas saber, ou crie uma operação entre os resultados de 2 tabuadas")
print(tabuada_do_)
# Out:
# printe qual tabuada de 1 a 10 tu desejas saber, ou crie uma operação entre os resultados de 2 tabuadas
# (5, 10, 15, 20, 25, 30, 35, 40, 45, 50)
