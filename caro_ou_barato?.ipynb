# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/caro_ou_barato%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
compras = ["comida1", "comida2", "comida3", "comida4", "comida5", "comida6", "comida7", "comida8", "comida9", "comida10", "comida11", "comida12", "comida13", "comida14",]
len(compras)
if len(compras) >= 15:
  print("vai ficar caro")
else:
  print ("razoavelmente barato")
# Out:
# razoavelmente barato
