# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/senha2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = (int(input("digite sua senha ")))
if senha == 1234:
  print("iniciando")
else:
  print("acesso negado")
# Out:
# digite sua senha 1234
# iniciando
