# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/p%C3%A3o_de_200_reais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
custopao = 200
dinheiro = int(input("quanto dinheiro vc tem?"))

if dinheiro >= 200:
  print("você comprou um único pão por 200 reais ")
else:
  print("você não comprou o pão, já que não tinha dinheiro o suficiente")
# Out:
# quanto dinheiro vc tem?43565436
# você comprou um único pão por 200 reais
