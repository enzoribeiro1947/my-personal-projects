# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/teste_de_elif_com_faixa_et%C3%A1reas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("qual a sua idade? "))

if idade >= 60:
  print("você é um idoso")
elif idade >= 18:
  print("você é um adulto")
elif idade >= 12:
  print("você é um adolescente")
elif idade < 12:
  print("você é uma criança")
# Out:
# qual a sua idade? 19
# você é um adulto
