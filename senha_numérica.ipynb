# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/senha_num%C3%A9rica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = int(input("crie a sua senha numérica "))
qlsenha = int(input("qual a sua senha"))
if qlsenha == (senha):
  print("acesso liberado")
else:
  print("acesso negado")
