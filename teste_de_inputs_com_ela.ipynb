# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/my-personal-projects/blob/main/teste_de_inputs_com_ela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade_dela = input("qual é a idade dela?")
nome_dela = input("qual é o nome dela?")
oq_representa = input("o'que ela representa para você?")

print(f"ela representa {oq_representa} para você, o nome dela é {nome_dela}, e a idade dela é {idade_dela}")
# Out:
# qual é a idade dela?13
# qual é o nome dela?Danny
# o'que ela representa para você?tudo
# ela representa tudo para você, o nome dela é Danny, e a idade dela é 13
